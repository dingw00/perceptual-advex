# %%
# python3 adv_train.py --batch_size 128 --arch trades-wrn --dataset cifar 
# --attack "FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)" --only_attack_correct

# %%
# Create a dictionary to simulate command line arguments


args_dict = {
    'include_checkpoint': True,  # Set to True or False based on your needs
    'checkpoint': 'data/checkpoints/wrn_40_2.pt',  # You can set a default value if needed
    # 'checkpoint': None,
    'arch': 'trades-wrn',
    'dataset': 'cifar',
    'dataset_path': '~/datasets',
    'num_epochs': 200,
    'batch_size': 128,
    'val_batches': 10,
    'log_dir': 'data/logs',
    'parallel': 1,
    'lpips_model': None,
    'only_attack_correct': True,
    'randomize_attack': False,
    'maximize_attack': False,
    'seed': 0,
    'continue': False,
    'keep_every': 1,
    'optim': 'sgd',
    'lr': 0.1,
    'lr_schedule': None,
    'clip_grad': 1.0,
    'attack': ["NoAttack()"] # ["FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)"]
}

# Create a namespace object from the dictionary
class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

# %%
from typing import Any, Callable, List, Optional, cast
import torch
import argparse
import numpy as np
import shutil
import glob
import time
import random
import os
from torch import nn
from tensorboardX import SummaryWriter

from perceptual_advex import evaluation
from perceptual_advex.utilities import add_dataset_model_arguments, \
     get_dataset_model, calculate_accuracy
from perceptual_advex.attacks import *
from perceptual_advex.models import FeatureModel

VAL_ITERS = 100


print("Cuda:", torch.cuda.is_available())

# Create a namespace from the dictionary
args = Namespace(**args_dict)

# Now you can access the arguments as if they were parsed from the command lin

if args.optim == 'adam':
    if args.lr is None:
        args.lr = 1e-3
    if args.lr_schedule is None:
        args.lr_schedule = '120'
    if args.num_epochs is None:
        args.num_epochs = 100
elif args.optim == 'sgd':
    if args.dataset.startswith('cifar'):
        if "resnet" in args.arch:
            if args.lr is None:
                args.lr = 1e-1
            if args.lr_schedule is None:
                args.lr_schedule = '75,90,100'
            if args.num_epochs is None:
                args.num_epochs = 100
        elif args.arch == "trades-wrn":
            if args.lr is None:
                args.lr = 1e-1
            if args.lr_schedule is None:
                args.lr_schedule = '80,140'
            if args.num_epochs is None:
                args.num_epochs = 200
        else:
            print(args.arch, "for cifar dataset!!!!")
    
    elif (
        args.dataset.startswith('imagenet')
        or args.dataset == 'bird_or_bicycle'
    ):
        if args.lr is None:
            args.lr = 1e-1
        if args.lr_schedule is None:
            args.lr_schedule = '30,60,80'
        if args.num_epochs is None:
            args.num_epochs = 90

print(vars(args))

torch.manual_seed(args.seed)
np.random.seed(args.seed)
random.seed(args.seed)

dataset, model = get_dataset_model(args)
if isinstance(model, FeatureModel):
    model.allow_train()
if torch.cuda.is_available():
    model.cuda()

if args.lpips_model is not None:
    _, lpips_model = get_dataset_model(
        args, checkpoint_fname=args.lpips_model)
    if torch.cuda.is_available():
        lpips_model.cuda()

train_loader, val_loader = dataset.make_loaders(
    workers=4, batch_size=args.batch_size)

attacks = [eval(attack_str) for attack_str in args.attack]
validation_attacks = [
    NoAttack(),
    LinfAttack(model, dataset_name=args.dataset,
               num_iterations=VAL_ITERS),
    L2Attack(model, dataset_name=args.dataset,
             num_iterations=VAL_ITERS),
    JPEGLinfAttack(model, dataset_name=args.dataset,
                   num_iterations=VAL_ITERS),
    FogAttack(model, dataset_name=args.dataset,
              num_iterations=VAL_ITERS),
    StAdvAttack(model, num_iterations=VAL_ITERS),
    ReColorAdvAttack(model, num_iterations=VAL_ITERS),
    LagrangePerceptualAttack(model, num_iterations=30),
]

flags = []
if args.only_attack_correct:
    flags.append('only_attack_correct')
if args.randomize_attack:
    flags.append('random')
if args.maximize_attack:
    flags.append('maximum')
if args.lpips_model:
    lpips_model_name, _ = os.path.splitext(os.path.basename(
        args.lpips_model))
    flags.append(lpips_model_name)

experiment_path_parts = [args.dataset, args.arch]
if args.optim != 'sgd':
    experiment_path_parts.append(args.optim)
attacks_part = '-'.join(args.attack + flags)
if len(attacks_part) > 255:
    attacks_part = (
        attacks_part
        .replace('model, ', '')
        .replace("'imagenet100', ", '')
        .replace("'cifar', ", '')
        .replace(", num_iterations=10", '')
    )
experiment_path_parts.append(attacks_part)
experiment_path = os.path.join(*experiment_path_parts)

iteration = 0
log_dir = os.path.join(args.log_dir, experiment_path)

writer = SummaryWriter(log_dir)

# optimizer
optimizer: optim.Optimizer
if args.optim == 'sgd':
    weight_decay = 1e-4 if (
        args.dataset.startswith('imagenet')
        or args.dataset == 'bird_or_bicycle'
    ) else 2e-4
    optimizer = optim.SGD(model.parameters(),
                          lr=args.lr,
                          momentum=0.9,
                          weight_decay=weight_decay)
elif args.optim == 'adam':
    optimizer = optim.Adam(model.parameters())
else:
    raise ValueError(f'invalid optimizer {args.optim}')

lr_drop_epochs = [int(epoch_str) for epoch_str in
                  args.lr_schedule.split(',')]

# check for checkpoints
def get_checkpoint_fnames():
    for checkpoint_fname in glob.glob(os.path.join(glob.escape(log_dir),
                                                   '*.ckpt.pth')):
        epoch = int(os.path.basename(checkpoint_fname).split('.')[0])
        if epoch < args.num_epochs:
            yield epoch, checkpoint_fname

start_epoch = 0
latest_checkpoint_epoch = -1
latest_checkpoint_fname = None
for epoch, checkpoint_fname in get_checkpoint_fnames():
    if epoch > latest_checkpoint_epoch:
        latest_checkpoint_epoch = epoch
        latest_checkpoint_fname = checkpoint_fname
if latest_checkpoint_fname is not None:
    state = torch.load(latest_checkpoint_fname)
    if 'iteration' in state:
        iteration = state['iteration']
    if isinstance(model, FeatureModel):
        model.model.load_state_dict(state['model'])
    else:
        model.load_state_dict(state['model'])
    if 'optimizer' in state:
        optimizer.load_state_dict(state['optimizer'])
    start_epoch = latest_checkpoint_epoch + 1
    adaptive_eps = state.get('adaptive_eps', {})

# parallelize
if torch.cuda.is_available():
    device_ids = list(range(args.parallel))
    model = nn.DataParallel(model, device_ids)
    attacks = [nn.DataParallel(attack, device_ids) for attack in attacks]
    validation_attacks = [nn.DataParallel(attack, device_ids)
                          for attack in validation_attacks]

# necessary to put training loop in a function because otherwise we get
# huge memory leaks
def run_iter(
    inputs: torch.Tensor,
    labels: torch.Tensor,
    iteration: int,
    train: bool = True,
    log_fn: Optional[Callable[[str, Any], Any]] = None,
):
    prefix = 'train' if train else 'val'
    if log_fn is None:
        log_fn = lambda tag, value: writer.add_scalar(
            f'{prefix}/{tag}', value, iteration)

    model.eval()  # set model to eval to generate adversarial examples

    if torch.cuda.is_available():
        inputs = inputs.cuda()
        labels = labels.cuda()

    if args.only_attack_correct:
        with torch.no_grad():
            orig_logits = model(inputs)
            to_attack = orig_logits.argmax(1) == labels
    else:
        to_attack = torch.ones_like(labels).bool()

    if args.randomize_attack:
        step_attacks = [random.choice(attacks)]
    else:
        step_attacks = attacks

    adv_inputs_list: List[torch.Tensor] = []
    for attack in step_attacks:
        attack_adv_inputs = inputs.clone()
        if to_attack.sum() > 0:
            attack_adv_inputs[to_attack] = attack(inputs[to_attack],
                                                  labels[to_attack])
        adv_inputs_list.append(attack_adv_inputs)
    adv_inputs: torch.Tensor = torch.cat(adv_inputs_list)

    all_labels = torch.cat([labels for attack in step_attacks])

    # FORWARD PASS
    if train:
        optimizer.zero_grad()
        model.train()  # now we set the model to train mode

    logits = model(adv_inputs)

    # CONSTRUCT LOSS
    loss = F.cross_entropy(logits, all_labels, reduction='none')
    if args.maximize_attack:
        loss, _ = loss.resize(len(step_attacks), inputs.size()[0]).max(0)
    loss = loss.mean()

    # LOGGING
    accuracy = calculate_accuracy(logits, all_labels)
    log_fn('loss', loss.item())
    log_fn('accuracy', accuracy.item())

    with torch.no_grad():
        for attack_index, attack in enumerate(step_attacks):
            if isinstance(attack, nn.DataParallel):
                attack_name = attack.module.__class__.__name__
            else:
                attack_name = attack.__class__.__name__
            attack_logits = logits[
                attack_index * inputs.size()[0]:
                (attack_index + 1) * inputs.size()[0]
            ]
            log_fn(f'loss/{attack_name}',
                   F.cross_entropy(attack_logits, labels).item())
            log_fn(f'accuracy/{attack_name}',
                   calculate_accuracy(attack_logits, labels).item())

    # if train:
    #     print(f'ITER {iteration:06d}',
    #           f'accuracy: {accuracy.item() * 100:5.1f}%',
    #           f'loss: {loss.item():.2f}',
    #           sep='\t')

    # OPTIMIZATION
    if train:
        loss.backward()

        # clip gradients and optimize
        nn.utils.clip_grad_value_(model.parameters(), args.clip_grad)
        optimizer.step()

for epoch in range(start_epoch, args.num_epochs):
    
    print('BEGIN VALIDATION')
    model.eval()
    if epoch == 0:
        evaluation.evaluate_against_attacks(
            model, validation_attacks, val_loader, parallel=args.parallel,
            writer=writer, iteration=iteration, num_batches=args.val_batches,
        )
    else:
        evaluation.evaluate_against_attacks(
            model, [NoAttack()], val_loader, parallel=args.parallel,
            writer=writer, iteration=iteration, num_batches=args.val_batches,
        )

    lr = args.lr
    for lr_drop_epoch in lr_drop_epochs:
        if epoch >= lr_drop_epoch:
            lr *= 0.1
    
    print(f'START EPOCH {epoch:04d} (lr={lr:.0e})')
    ts = time.time()
    for batch_index, (inputs, labels) in enumerate(train_loader):
        # ramp-up learning rate for SGD
        if epoch < 5 and args.optim == 'sgd' and args.lr >= 0.1:
            lr = (iteration + 1) / (5 * len(train_loader)) * args.lr
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        
        run_iter(inputs, labels, iteration)
        iteration += 1
    print(f'END EPOCH {epoch:04d}', "time spent:", time.time()-ts)
    
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # VALIDATION
    print('BEGIN VALIDATION')
    model.eval()
    if (epoch + 1) % 20 == 0:
        evaluation.evaluate_against_attacks(
            model, validation_attacks, val_loader, parallel=args.parallel,
            writer=writer, iteration=iteration, num_batches=args.val_batches,
        )

    checkpoint_fname = os.path.join(log_dir, f'{epoch:04d}.ckpt.pth')
    print(f'CHECKPOINT {checkpoint_fname}')
    checkpoint_model = model
    if isinstance(checkpoint_model, nn.DataParallel):
        checkpoint_model = checkpoint_model.module
    if isinstance(checkpoint_model, FeatureModel):
        checkpoint_model = checkpoint_model.model
    state = {
        'model': checkpoint_model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'iteration': iteration,
        'arch': args.arch,
    }
    torch.save(state, checkpoint_fname)

    # delete extraneous checkpoints
    last_keep_checkpoint = (epoch // args.keep_every) * args.keep_every
    for epoch, checkpoint_fname in get_checkpoint_fnames():
        if epoch < last_keep_checkpoint and epoch % args.keep_every != 0:
            print(f'  remove {checkpoint_fname}')
            os.remove(checkpoint_fname)

print('BEGIN EVALUATION')
model.eval()

evaluation.evaluate_against_attacks(
    model, validation_attacks, val_loader, parallel=args.parallel,
)
print('END EVALUATION')
# Out:
# Cuda: True
# {'include_checkpoint': True, 'checkpoint': 'data/checkpoints/wrn_40_2.pt', 'arch': 'trades-wrn', 'dataset': 'cifar', 'dataset_path': '~/datasets', 'num_epochs': 200, 'batch_size': 128, 'val_batches': 10, 'log_dir': 'data/logs', 'parallel': 1, 'lpips_model': None, 'only_attack_correct': True, 'randomize_attack': False, 'maximize_attack': False, 'seed': 0, 'continue': False, 'keep_every': 1, 'optim': 'sgd', 'lr': 0.1, 'lr_schedule': '80,140', 'clip_grad': 1.0, 'attack': ['NoAttack()']}
# ==> Preparing dataset cifar..
# Files already downloaded and verified
# Files already downloaded and verified
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 95.2%
# START EPOCH 0000 (lr=1e-01)
# END EPOCH 0000 time spent: 32.98800611495972
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0000.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 85.6%
# START EPOCH 0001 (lr=1e-01)
# END EPOCH 0001 time spent: 32.1663761138916
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0001.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 85.2%
# START EPOCH 0002 (lr=1e-01)
# END EPOCH 0002 time spent: 33.436198472976685
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0002.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 82.0%
# START EPOCH 0003 (lr=1e-01)
# END EPOCH 0003 time spent: 33.127142667770386
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0003.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 77.5%
# START EPOCH 0004 (lr=1e-01)
# END EPOCH 0004 time spent: 33.05504131317139
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0004.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 80.9%
# START EPOCH 0005 (lr=1e-01)
# END EPOCH 0005 time spent: 32.580647468566895
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0005.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.4%
# START EPOCH 0006 (lr=1e-01)
# END EPOCH 0006 time spent: 32.659956216812134
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0006.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 83.8%
# START EPOCH 0007 (lr=1e-01)
# END EPOCH 0007 time spent: 33.459837675094604
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0007.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 86.6%
# START EPOCH 0008 (lr=1e-01)
# END EPOCH 0008 time spent: 32.77573609352112
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0008.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 87.7%
# START EPOCH 0009 (lr=1e-01)
# END EPOCH 0009 time spent: 33.23876118659973
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0009.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.0%
# START EPOCH 0010 (lr=1e-01)
# END EPOCH 0010 time spent: 33.34611773490906
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0010.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.1%
# START EPOCH 0011 (lr=1e-01)
# END EPOCH 0011 time spent: 33.38172793388367
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0011.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.0%
# START EPOCH 0012 (lr=1e-01)
# END EPOCH 0012 time spent: 33.029292821884155
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0012.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.6%
# START EPOCH 0013 (lr=1e-01)
# END EPOCH 0013 time spent: 32.08666396141052
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0013.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.9%
# START EPOCH 0014 (lr=1e-01)
# END EPOCH 0014 time spent: 32.77031660079956
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0014.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 87.8%
# START EPOCH 0015 (lr=1e-01)
# END EPOCH 0015 time spent: 32.099971294403076
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0015.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 87.7%
# START EPOCH 0016 (lr=1e-01)
# END EPOCH 0016 time spent: 33.390103578567505
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0016.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.7%
# START EPOCH 0017 (lr=1e-01)
# END EPOCH 0017 time spent: 32.22478175163269
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0017.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.1%
# START EPOCH 0018 (lr=1e-01)
# END EPOCH 0018 time spent: 33.48586463928223
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0018.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 85.8%
# START EPOCH 0019 (lr=1e-01)
# END EPOCH 0019 time spent: 33.09952688217163
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.5%
# ATTACK LinfAttack	accuracy: 0.0%
# ATTACK L2Attack	accuracy: 0.9%
# ATTACK JPEGLinfAttack	accuracy: 0.0%
# ATTACK FogAttack	accuracy: 11.2%
# ATTACK StAdvAttack	accuracy: 0.0%
# ATTACK ReColorAdvAttack	accuracy: 0.5%
# ATTACK LagrangePerceptualAttack	accuracy: 13.1%
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0019.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.6%
# START EPOCH 0020 (lr=1e-01)
# END EPOCH 0020 time spent: 33.62951731681824
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0020.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.9%
# START EPOCH 0021 (lr=1e-01)
# END EPOCH 0021 time spent: 32.83264231681824
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0021.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.9%
# START EPOCH 0022 (lr=1e-01)
# END EPOCH 0022 time spent: 32.81706738471985
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0022.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 86.6%
# START EPOCH 0023 (lr=1e-01)
# END EPOCH 0023 time spent: 32.98976135253906
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0023.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.8%
# START EPOCH 0024 (lr=1e-01)
# END EPOCH 0024 time spent: 33.32373356819153
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0024.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.1%
# START EPOCH 0025 (lr=1e-01)
# END EPOCH 0025 time spent: 32.2148642539978
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0025.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 87.1%
# START EPOCH 0026 (lr=1e-01)
# END EPOCH 0026 time spent: 33.03652739524841
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0026.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.1%
# START EPOCH 0027 (lr=1e-01)
# END EPOCH 0027 time spent: 32.60385823249817
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0027.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.7%
# START EPOCH 0028 (lr=1e-01)
# END EPOCH 0028 time spent: 32.393961668014526
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0028.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 90.4%
# START EPOCH 0029 (lr=1e-01)
# END EPOCH 0029 time spent: 33.38027882575989
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0029.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.8%
# START EPOCH 0030 (lr=1e-01)
# END EPOCH 0030 time spent: 33.11945462226868
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0030.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.1%
# START EPOCH 0031 (lr=1e-01)
# END EPOCH 0031 time spent: 33.7061812877655
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0031.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 86.4%
# START EPOCH 0032 (lr=1e-01)
# END EPOCH 0032 time spent: 33.01771426200867
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0032.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.7%
# START EPOCH 0033 (lr=1e-01)
# END EPOCH 0033 time spent: 33.952226638793945
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0033.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.2%
# START EPOCH 0034 (lr=1e-01)
# END EPOCH 0034 time spent: 33.4163134098053
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0034.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 90.7%
# START EPOCH 0035 (lr=1e-01)
# END EPOCH 0035 time spent: 32.547778844833374
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0035.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 86.6%
# START EPOCH 0036 (lr=1e-01)
# END EPOCH 0036 time spent: 32.87557792663574
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0036.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 90.4%
# START EPOCH 0037 (lr=1e-01)
# END EPOCH 0037 time spent: 33.275890588760376
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0037.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 90.9%
# START EPOCH 0038 (lr=1e-01)
# END EPOCH 0038 time spent: 33.10205960273743
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0038.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 90.1%
# START EPOCH 0039 (lr=1e-01)
# END EPOCH 0039 time spent: 32.400750160217285
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.4%
# ATTACK LinfAttack	accuracy: 0.0%
# ATTACK L2Attack	accuracy: 0.1%
# ATTACK JPEGLinfAttack	accuracy: 0.0%
# ATTACK FogAttack	accuracy: 8.0%
# ATTACK StAdvAttack	accuracy: 0.0%
# ATTACK ReColorAdvAttack	accuracy: 0.9%
# ATTACK LagrangePerceptualAttack	accuracy: 9.0%
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0039.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.6%
# START EPOCH 0040 (lr=1e-01)
# END EPOCH 0040 time spent: 31.55017876625061
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0040.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.4%
# START EPOCH 0041 (lr=1e-01)
# END EPOCH 0041 time spent: 33.88158082962036
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0041.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.1%
# START EPOCH 0042 (lr=1e-01)
# END EPOCH 0042 time spent: 33.3269259929657
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0042.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 90.2%
# START EPOCH 0043 (lr=1e-01)
# END EPOCH 0043 time spent: 32.950828552246094
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0043.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 87.3%
# START EPOCH 0044 (lr=1e-01)
# END EPOCH 0044 time spent: 32.865941286087036
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0044.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.7%
# START EPOCH 0045 (lr=1e-01)
# END EPOCH 0045 time spent: 33.22193622589111
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0045.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.4%
# START EPOCH 0046 (lr=1e-01)
# END EPOCH 0046 time spent: 33.96396327018738
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0046.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 91.0%
# START EPOCH 0047 (lr=1e-01)
# END EPOCH 0047 time spent: 32.48129320144653
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0047.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 90.0%
# START EPOCH 0048 (lr=1e-01)
# END EPOCH 0048 time spent: 33.66488766670227
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0048.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.7%
# START EPOCH 0049 (lr=1e-01)
# END EPOCH 0049 time spent: 33.123743295669556
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0049.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 88.1%
# START EPOCH 0050 (lr=1e-01)
# END EPOCH 0050 time spent: 32.64549160003662
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0050.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.7%
# START EPOCH 0051 (lr=1e-01)
# END EPOCH 0051 time spent: 33.528722524642944
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/NoAttack()-only_attack_correct/0051.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 89.6%
# START EPOCH 0052 (lr=1e-01)
