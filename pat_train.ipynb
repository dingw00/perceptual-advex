# %%
# python3 adv_train.py --batch_size 128 --arch trades-wrn --dataset cifar 
# --attack "FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)" --only_attack_correct

# %%
# Create a dictionary to simulate command line arguments


args_dict = {
    'include_checkpoint': True,  # Set to True or False based on your needs
    'checkpoint': 'data/checkpoints/wrn_40_2.pt',  # You can set a default value if needed
    # 'checkpoint': None,
    'arch': 'trades-wrn',
    'dataset': 'cifar',
    'dataset_path': '~/datasets',
    'num_epochs': 200,
    'batch_size': 128,
    'val_batches': 10,
    'log_dir': 'data/logs',
    'parallel': 1,
    'lpips_model': None,
    'only_attack_correct': True,
    'randomize_attack': False,
    'maximize_attack': False,
    'seed': 0,
    'continue': False,
    'keep_every': 1,
    'optim': 'sgd',
    'lr': 0.1,
    'lr_schedule': None,
    'clip_grad': 1.0,
    'attack': ["FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)"]
}

# Create a namespace object from the dictionary
class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

# %%
from typing import Any, Callable, List, Optional, cast
import torch
import argparse
import numpy as np
import shutil
import glob
import time
import random
import os
from torch import nn
from tensorboardX import SummaryWriter

from perceptual_advex import evaluation
from perceptual_advex.utilities import add_dataset_model_arguments, \
     get_dataset_model, calculate_accuracy
from perceptual_advex.attacks import *
from perceptual_advex.models import FeatureModel

VAL_ITERS = 100


print("Cuda:", torch.cuda.is_available())

# Create a namespace from the dictionary
args = Namespace(**args_dict)

# Now you can access the arguments as if they were parsed from the command lin

if args.optim == 'adam':
    if args.lr is None:
        args.lr = 1e-3
    if args.lr_schedule is None:
        args.lr_schedule = '120'
    if args.num_epochs is None:
        args.num_epochs = 100
elif args.optim == 'sgd':
    if args.dataset.startswith('cifar'):
        if "resnet" in args.arch:
            if args.lr is None:
                args.lr = 1e-1
            if args.lr_schedule is None:
                args.lr_schedule = '75,90,100'
            if args.num_epochs is None:
                args.num_epochs = 100
        elif args.arch == "trades-wrn":
            if args.lr is None:
                args.lr = 1e-1
            if args.lr_schedule is None:
                args.lr_schedule = '80,140'
            if args.num_epochs is None:
                args.num_epochs = 200
        else:
            print(args.arch, "for cifar dataset!!!!")
    
    elif (
        args.dataset.startswith('imagenet')
        or args.dataset == 'bird_or_bicycle'
    ):
        if args.lr is None:
            args.lr = 1e-1
        if args.lr_schedule is None:
            args.lr_schedule = '30,60,80'
        if args.num_epochs is None:
            args.num_epochs = 90

print(vars(args))

torch.manual_seed(args.seed)
np.random.seed(args.seed)
random.seed(args.seed)

dataset, model = get_dataset_model(args)
if isinstance(model, FeatureModel):
    model.allow_train()
if torch.cuda.is_available():
    model.cuda()

if args.lpips_model is not None:
    _, lpips_model = get_dataset_model(
        args, checkpoint_fname=args.lpips_model)
    if torch.cuda.is_available():
        lpips_model.cuda()

train_loader, val_loader = dataset.make_loaders(
    workers=4, batch_size=args.batch_size)

attacks = [eval(attack_str) for attack_str in args.attack]
validation_attacks = [
    NoAttack(),
    LinfAttack(model, dataset_name=args.dataset,
               num_iterations=VAL_ITERS),
    L2Attack(model, dataset_name=args.dataset,
             num_iterations=VAL_ITERS),
    JPEGLinfAttack(model, dataset_name=args.dataset,
                   num_iterations=VAL_ITERS),
    FogAttack(model, dataset_name=args.dataset,
              num_iterations=VAL_ITERS),
    StAdvAttack(model, num_iterations=VAL_ITERS),
    ReColorAdvAttack(model, num_iterations=VAL_ITERS),
    LagrangePerceptualAttack(model, num_iterations=30),
]

flags = []
if args.only_attack_correct:
    flags.append('only_attack_correct')
if args.randomize_attack:
    flags.append('random')
if args.maximize_attack:
    flags.append('maximum')
if args.lpips_model:
    lpips_model_name, _ = os.path.splitext(os.path.basename(
        args.lpips_model))
    flags.append(lpips_model_name)

experiment_path_parts = [args.dataset, args.arch]
if args.optim != 'sgd':
    experiment_path_parts.append(args.optim)
attacks_part = '-'.join(args.attack + flags)
if len(attacks_part) > 255:
    attacks_part = (
        attacks_part
        .replace('model, ', '')
        .replace("'imagenet100', ", '')
        .replace("'cifar', ", '')
        .replace(", num_iterations=10", '')
    )
experiment_path_parts.append(attacks_part)
experiment_path = os.path.join(*experiment_path_parts)

iteration = 0
log_dir = os.path.join(args.log_dir, experiment_path)

writer = SummaryWriter(log_dir)

# optimizer
optimizer: optim.Optimizer
if args.optim == 'sgd':
    weight_decay = 1e-4 if (
        args.dataset.startswith('imagenet')
        or args.dataset == 'bird_or_bicycle'
    ) else 2e-4
    optimizer = optim.SGD(model.parameters(),
                          lr=args.lr,
                          momentum=0.9,
                          weight_decay=weight_decay)
elif args.optim == 'adam':
    optimizer = optim.Adam(model.parameters())
else:
    raise ValueError(f'invalid optimizer {args.optim}')

lr_drop_epochs = [int(epoch_str) for epoch_str in
                  args.lr_schedule.split(',')]

# check for checkpoints
def get_checkpoint_fnames():
    for checkpoint_fname in glob.glob(os.path.join(glob.escape(log_dir),
                                                   '*.ckpt.pth')):
        epoch = int(os.path.basename(checkpoint_fname).split('.')[0])
        if epoch < args.num_epochs:
            yield epoch, checkpoint_fname

start_epoch = 0
latest_checkpoint_epoch = -1
latest_checkpoint_fname = None
for epoch, checkpoint_fname in get_checkpoint_fnames():
    if epoch > latest_checkpoint_epoch:
        latest_checkpoint_epoch = epoch
        latest_checkpoint_fname = checkpoint_fname
if latest_checkpoint_fname is not None:
    state = torch.load(latest_checkpoint_fname)
    if 'iteration' in state:
        iteration = state['iteration']
    if isinstance(model, FeatureModel):
        model.model.load_state_dict(state['model'])
    else:
        model.load_state_dict(state['model'])
    if 'optimizer' in state:
        optimizer.load_state_dict(state['optimizer'])
    start_epoch = latest_checkpoint_epoch + 1
    adaptive_eps = state.get('adaptive_eps', {})

# parallelize
if torch.cuda.is_available():
    device_ids = list(range(args.parallel))
    model = nn.DataParallel(model, device_ids)
    attacks = [nn.DataParallel(attack, device_ids) for attack in attacks]
    validation_attacks = [nn.DataParallel(attack, device_ids)
                          for attack in validation_attacks]

# necessary to put training loop in a function because otherwise we get
# huge memory leaks
def run_iter(
    inputs: torch.Tensor,
    labels: torch.Tensor,
    iteration: int,
    train: bool = True,
    log_fn: Optional[Callable[[str, Any], Any]] = None,
):
    prefix = 'train' if train else 'val'
    if log_fn is None:
        log_fn = lambda tag, value: writer.add_scalar(
            f'{prefix}/{tag}', value, iteration)

    model.eval()  # set model to eval to generate adversarial examples

    if torch.cuda.is_available():
        inputs = inputs.cuda()
        labels = labels.cuda()

    if args.only_attack_correct:
        with torch.no_grad():
            orig_logits = model(inputs)
            to_attack = orig_logits.argmax(1) == labels
    else:
        to_attack = torch.ones_like(labels).bool()

    if args.randomize_attack:
        step_attacks = [random.choice(attacks)]
    else:
        step_attacks = attacks

    adv_inputs_list: List[torch.Tensor] = []
    for attack in step_attacks:
        attack_adv_inputs = inputs.clone()
        if to_attack.sum() > 0:
            attack_adv_inputs[to_attack] = attack(inputs[to_attack],
                                                  labels[to_attack])
        adv_inputs_list.append(attack_adv_inputs)
    adv_inputs: torch.Tensor = torch.cat(adv_inputs_list)

    all_labels = torch.cat([labels for attack in step_attacks])

    # FORWARD PASS
    if train:
        optimizer.zero_grad()
        model.train()  # now we set the model to train mode

    logits = model(adv_inputs)

    # CONSTRUCT LOSS
    loss = F.cross_entropy(logits, all_labels, reduction='none')
    if args.maximize_attack:
        loss, _ = loss.resize(len(step_attacks), inputs.size()[0]).max(0)
    loss = loss.mean()

    # LOGGING
    accuracy = calculate_accuracy(logits, all_labels)
    log_fn('loss', loss.item())
    log_fn('accuracy', accuracy.item())

    with torch.no_grad():
        for attack_index, attack in enumerate(step_attacks):
            if isinstance(attack, nn.DataParallel):
                attack_name = attack.module.__class__.__name__
            else:
                attack_name = attack.__class__.__name__
            attack_logits = logits[
                attack_index * inputs.size()[0]:
                (attack_index + 1) * inputs.size()[0]
            ]
            log_fn(f'loss/{attack_name}',
                   F.cross_entropy(attack_logits, labels).item())
            log_fn(f'accuracy/{attack_name}',
                   calculate_accuracy(attack_logits, labels).item())

    # if train:
    #     print(f'ITER {iteration:06d}',
    #           f'accuracy: {accuracy.item() * 100:5.1f}%',
    #           f'loss: {loss.item():.2f}',
    #           sep='\t')

    # OPTIMIZATION
    if train:
        loss.backward()

        # clip gradients and optimize
        nn.utils.clip_grad_value_(model.parameters(), args.clip_grad)
        optimizer.step()

for epoch in range(start_epoch, args.num_epochs):
    
    print('BEGIN VALIDATION')
    model.eval()
    if epoch == -1:
        evaluation.evaluate_against_attacks(
            model, validation_attacks, val_loader, parallel=args.parallel,
            writer=writer, iteration=iteration, num_batches=args.val_batches,
        )
    else:
        evaluation.evaluate_against_attacks(
            model, [NoAttack()], val_loader, parallel=args.parallel,
            writer=writer, iteration=iteration, num_batches=args.val_batches,
        )

    lr = args.lr
    for lr_drop_epoch in lr_drop_epochs:
        if epoch >= lr_drop_epoch:
            lr *= 0.1
    
    print(f'START EPOCH {epoch:04d} (lr={lr:.0e})')
    ts = time.time()
    for batch_index, (inputs, labels) in enumerate(train_loader):
        # ramp-up learning rate for SGD
        if epoch < 5 and args.optim == 'sgd' and args.lr >= 0.1:
            lr = (iteration + 1) / (5 * len(train_loader)) * args.lr
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        
        run_iter(inputs, labels, iteration)
        iteration += 1
    print(f'END EPOCH {epoch:04d}', "time spent:", time.time()-ts)
    
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # VALIDATION
    print('BEGIN VALIDATION')
    model.eval()
    if (epoch + 1) % 20 == 0:
        evaluation.evaluate_against_attacks(
            model, validation_attacks, val_loader, parallel=args.parallel,
            writer=writer, iteration=iteration, num_batches=args.val_batches,
        )

    checkpoint_fname = os.path.join(log_dir, f'{epoch:04d}.ckpt.pth')
    print(f'CHECKPOINT {checkpoint_fname}')
    checkpoint_model = model
    if isinstance(checkpoint_model, nn.DataParallel):
        checkpoint_model = checkpoint_model.module
    if isinstance(checkpoint_model, FeatureModel):
        checkpoint_model = checkpoint_model.model
    state = {
        'model': checkpoint_model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'iteration': iteration,
        'arch': args.arch,
    }
    torch.save(state, checkpoint_fname)

    # delete extraneous checkpoints
    last_keep_checkpoint = (epoch // args.keep_every) * args.keep_every
    for epoch, checkpoint_fname in get_checkpoint_fnames():
        if epoch < last_keep_checkpoint and epoch % args.keep_every != 0:
            print(f'  remove {checkpoint_fname}')
            os.remove(checkpoint_fname)

print('BEGIN EVALUATION')
model.eval()

evaluation.evaluate_against_attacks(
    model, validation_attacks, val_loader, parallel=args.parallel,
)
print('END EVALUATION')
# Out:
# Cuda: True
# {'include_checkpoint': True, 'checkpoint': 'data/checkpoints/wrn_40_2.pt', 'arch': 'trades-wrn', 'dataset': 'cifar', 'dataset_path': '~/datasets', 'num_epochs': 200, 'batch_size': 128, 'val_batches': 10, 'log_dir': 'data/logs', 'parallel': 1, 'lpips_model': None, 'only_attack_correct': True, 'randomize_attack': False, 'maximize_attack': False, 'seed': 0, 'continue': False, 'keep_every': 1, 'optim': 'sgd', 'lr': 0.1, 'lr_schedule': '80,140', 'clip_grad': 1.0, 'attack': ['FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)']}
# ==> Preparing dataset cifar..
# Files already downloaded and verified
# Files already downloaded and verified
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.5%
# START EPOCH 0020 (lr=1e-01)
# END EPOCH 0020 time spent: 247.5441472530365
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0020.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.7%
# START EPOCH 0021 (lr=1e-01)
# END EPOCH 0021 time spent: 249.6335151195526
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0021.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.9%
# START EPOCH 0022 (lr=1e-01)
# END EPOCH 0022 time spent: 248.40261697769165
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0022.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.8%
# START EPOCH 0023 (lr=1e-01)
# END EPOCH 0023 time spent: 247.89768314361572
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0023.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.3%
# START EPOCH 0024 (lr=1e-01)
# END EPOCH 0024 time spent: 248.30959129333496
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0024.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.3%
# START EPOCH 0025 (lr=1e-01)
# END EPOCH 0025 time spent: 248.4364778995514
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0025.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.3%
# START EPOCH 0026 (lr=1e-01)
# END EPOCH 0026 time spent: 248.6830337047577
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0026.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 60.2%
# START EPOCH 0027 (lr=1e-01)
# END EPOCH 0027 time spent: 248.4121437072754
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0027.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.1%
# START EPOCH 0028 (lr=1e-01)
# END EPOCH 0028 time spent: 248.39404153823853
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0028.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 64.2%
# START EPOCH 0029 (lr=1e-01)
# END EPOCH 0029 time spent: 248.80459094047546
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0029.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.3%
# START EPOCH 0030 (lr=1e-01)
# END EPOCH 0030 time spent: 246.73109793663025
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0030.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.8%
# START EPOCH 0031 (lr=1e-01)
# END EPOCH 0031 time spent: 248.1027021408081
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0031.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.0%
# START EPOCH 0032 (lr=1e-01)
# END EPOCH 0032 time spent: 247.41309118270874
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0032.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.8%
# START EPOCH 0033 (lr=1e-01)
# END EPOCH 0033 time spent: 248.19620823860168
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0033.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.8%
# START EPOCH 0034 (lr=1e-01)
# END EPOCH 0034 time spent: 248.46907210350037
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0034.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 53.3%
# START EPOCH 0035 (lr=1e-01)
# END EPOCH 0035 time spent: 247.3618607521057
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0035.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.7%
# START EPOCH 0036 (lr=1e-01)
# END EPOCH 0036 time spent: 247.12792420387268
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0036.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.9%
# START EPOCH 0037 (lr=1e-01)
# END EPOCH 0037 time spent: 247.78236889839172
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0037.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.0%
# START EPOCH 0038 (lr=1e-01)
# END EPOCH 0038 time spent: 247.69816970825195
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0038.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.3%
# START EPOCH 0039 (lr=1e-01)
# END EPOCH 0039 time spent: 247.25727701187134
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 60.8%
# ATTACK LinfAttack	accuracy: 23.0%
# ATTACK L2Attack	accuracy: 26.3%
# ATTACK JPEGLinfAttack	accuracy: 13.7%
# ATTACK FogAttack	accuracy: 4.2%
# ATTACK StAdvAttack	accuracy: 44.9%
# ATTACK ReColorAdvAttack	accuracy: 53.1%
# ATTACK LagrangePerceptualAttack	accuracy: 25.5%
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0039.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.2%
# START EPOCH 0040 (lr=1e-01)
# END EPOCH 0040 time spent: 247.71996068954468
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0040.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 53.8%
# START EPOCH 0041 (lr=1e-01)
# END EPOCH 0041 time spent: 249.05420112609863
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0041.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.1%
# START EPOCH 0042 (lr=1e-01)
# END EPOCH 0042 time spent: 249.09072947502136
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0042.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.9%
# START EPOCH 0043 (lr=1e-01)
# END EPOCH 0043 time spent: 248.52396941184998
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0043.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 60.9%
# START EPOCH 0044 (lr=1e-01)
# END EPOCH 0044 time spent: 249.08192706108093
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0044.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.5%
# START EPOCH 0045 (lr=1e-01)
# END EPOCH 0045 time spent: 247.76463174819946
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0045.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.0%
# START EPOCH 0046 (lr=1e-01)
# END EPOCH 0046 time spent: 249.53173184394836
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0046.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.3%
# START EPOCH 0047 (lr=1e-01)
# END EPOCH 0047 time spent: 248.4843852519989
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0047.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.1%
# START EPOCH 0048 (lr=1e-01)
# END EPOCH 0048 time spent: 248.71100115776062
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0048.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.9%
# START EPOCH 0049 (lr=1e-01)
# END EPOCH 0049 time spent: 248.1692864894867
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0049.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 60.3%
# START EPOCH 0050 (lr=1e-01)
# END EPOCH 0050 time spent: 249.0889093875885
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0050.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.3%
# START EPOCH 0051 (lr=1e-01)
# END EPOCH 0051 time spent: 249.049809217453
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0051.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 55.9%
# START EPOCH 0052 (lr=1e-01)
# END EPOCH 0052 time spent: 249.96465134620667
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0052.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.8%
# START EPOCH 0053 (lr=1e-01)
# END EPOCH 0053 time spent: 249.12634372711182
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0053.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.5%
# START EPOCH 0054 (lr=1e-01)
# END EPOCH 0054 time spent: 248.30715942382812
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0054.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.3%
# START EPOCH 0055 (lr=1e-01)
# END EPOCH 0055 time spent: 247.7062783241272
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0055.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.3%
# START EPOCH 0056 (lr=1e-01)
# END EPOCH 0056 time spent: 248.5605444908142
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0056.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.0%
# START EPOCH 0057 (lr=1e-01)
# END EPOCH 0057 time spent: 248.742018699646
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0057.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.8%
# START EPOCH 0058 (lr=1e-01)
# END EPOCH 0058 time spent: 248.35458087921143
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0058.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.7%
# START EPOCH 0059 (lr=1e-01)
# END EPOCH 0059 time spent: 248.5652997493744
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.5%
# ATTACK LinfAttack	accuracy: 21.9%
# ATTACK L2Attack	accuracy: 24.8%
# ATTACK JPEGLinfAttack	accuracy: 10.9%
# ATTACK FogAttack	accuracy: 7.3%
# ATTACK StAdvAttack	accuracy: 43.0%
# ATTACK ReColorAdvAttack	accuracy: 53.6%
# ATTACK LagrangePerceptualAttack	accuracy: 18.8%
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0059.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.4%
# START EPOCH 0060 (lr=1e-01)
# END EPOCH 0060 time spent: 249.67109179496765
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0060.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 64.7%
# START EPOCH 0061 (lr=1e-01)
# END EPOCH 0061 time spent: 248.37445378303528
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0061.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.3%
# START EPOCH 0062 (lr=1e-01)
# END EPOCH 0062 time spent: 247.39701795578003
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0062.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.8%
# START EPOCH 0063 (lr=1e-01)
# END EPOCH 0063 time spent: 249.5036940574646
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0063.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 54.5%
# START EPOCH 0064 (lr=1e-01)
# END EPOCH 0064 time spent: 248.24047756195068
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0064.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.4%
# START EPOCH 0065 (lr=1e-01)
# END EPOCH 0065 time spent: 249.56069159507751
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0065.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.1%
# START EPOCH 0066 (lr=1e-01)
# END EPOCH 0066 time spent: 249.80578589439392
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0066.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.7%
# START EPOCH 0067 (lr=1e-01)
# END EPOCH 0067 time spent: 250.1633598804474
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0067.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.1%
# START EPOCH 0068 (lr=1e-01)
# END EPOCH 0068 time spent: 249.49297404289246
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0068.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.5%
# START EPOCH 0069 (lr=1e-01)
# END EPOCH 0069 time spent: 249.66912603378296
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0069.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 52.4%
# START EPOCH 0070 (lr=1e-01)
# END EPOCH 0070 time spent: 250.9273271560669
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0070.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.7%
# START EPOCH 0071 (lr=1e-01)
# END EPOCH 0071 time spent: 247.96231174468994
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0071.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 56.9%
# START EPOCH 0072 (lr=1e-01)
# END EPOCH 0072 time spent: 249.73866629600525
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0072.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.4%
# START EPOCH 0073 (lr=1e-01)
# END EPOCH 0073 time spent: 247.5481870174408
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0073.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.4%
# START EPOCH 0074 (lr=1e-01)
# END EPOCH 0074 time spent: 250.81451320648193
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0074.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.8%
# START EPOCH 0075 (lr=1e-01)
# END EPOCH 0075 time spent: 248.80629587173462
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0075.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 57.2%
# START EPOCH 0076 (lr=1e-01)
# END EPOCH 0076 time spent: 250.5582275390625
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0076.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.7%
# START EPOCH 0077 (lr=1e-01)
# END EPOCH 0077 time spent: 250.36156725883484
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0077.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 59.0%
# START EPOCH 0078 (lr=1e-01)
# END EPOCH 0078 time spent: 248.1906235218048
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0078.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 58.0%
# START EPOCH 0079 (lr=1e-01)
# END EPOCH 0079 time spent: 249.91151547431946
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.3%
# ATTACK LinfAttack	accuracy: 25.1%
# ATTACK L2Attack	accuracy: 27.1%
# ATTACK JPEGLinfAttack	accuracy: 11.2%
# ATTACK FogAttack	accuracy: 8.6%
# ATTACK StAdvAttack	accuracy: 45.9%
# ATTACK ReColorAdvAttack	accuracy: 54.4%
# ATTACK LagrangePerceptualAttack	accuracy: 22.7%
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0079.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 60.5%
# START EPOCH 0080 (lr=1e-02)
# END EPOCH 0080 time spent: 248.4732048511505
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0080.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 68.2%
# START EPOCH 0081 (lr=1e-02)
# END EPOCH 0081 time spent: 249.84111428260803
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0081.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.8%
# START EPOCH 0082 (lr=1e-02)
# END EPOCH 0082 time spent: 249.4759647846222
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0082.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.2%
# START EPOCH 0083 (lr=1e-02)
# END EPOCH 0083 time spent: 248.98302960395813
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0083.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.0%
# START EPOCH 0084 (lr=1e-02)
# END EPOCH 0084 time spent: 248.73227882385254
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0084.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 68.7%
# START EPOCH 0085 (lr=1e-02)
# END EPOCH 0085 time spent: 249.07754349708557
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0085.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 60.5%
# START EPOCH 0086 (lr=1e-02)
# END EPOCH 0086 time spent: 249.18717169761658
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0086.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.1%
# START EPOCH 0087 (lr=1e-02)
# END EPOCH 0087 time spent: 248.11306500434875
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0087.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.2%
# START EPOCH 0088 (lr=1e-02)
# END EPOCH 0088 time spent: 249.2143886089325
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0088.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.0%
# START EPOCH 0089 (lr=1e-02)
# END EPOCH 0089 time spent: 249.56318354606628
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0089.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 64.7%
# START EPOCH 0090 (lr=1e-02)
# END EPOCH 0090 time spent: 249.03436827659607
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0090.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 68.5%
# START EPOCH 0091 (lr=1e-02)
# END EPOCH 0091 time spent: 249.2289514541626
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0091.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 64.4%
# START EPOCH 0092 (lr=1e-02)
# END EPOCH 0092 time spent: 250.2025065422058
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0092.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.0%
# START EPOCH 0093 (lr=1e-02)
# END EPOCH 0093 time spent: 248.57390928268433
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0093.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.8%
# START EPOCH 0094 (lr=1e-02)
# END EPOCH 0094 time spent: 249.3137867450714
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0094.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 69.5%
# START EPOCH 0095 (lr=1e-02)
# END EPOCH 0095 time spent: 249.67163038253784
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0095.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 67.1%
# START EPOCH 0096 (lr=1e-02)
# END EPOCH 0096 time spent: 249.8391683101654
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0096.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 69.9%
# START EPOCH 0097 (lr=1e-02)
# END EPOCH 0097 time spent: 248.3287832736969
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0097.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 69.5%
# START EPOCH 0098 (lr=1e-02)
# END EPOCH 0098 time spent: 250.18784308433533
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0098.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 60.9%
# START EPOCH 0099 (lr=1e-02)
# END EPOCH 0099 time spent: 250.44196724891663
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.3%
# ATTACK LinfAttack	accuracy: 26.2%
# ATTACK L2Attack	accuracy: 27.0%
# ATTACK JPEGLinfAttack	accuracy: 10.7%
# ATTACK FogAttack	accuracy: 10.2%
# ATTACK StAdvAttack	accuracy: 51.0%
# ATTACK ReColorAdvAttack	accuracy: 58.9%
# ATTACK LagrangePerceptualAttack	accuracy: 30.4%
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0099.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.7%
# START EPOCH 0100 (lr=1e-02)
# END EPOCH 0100 time spent: 250.92147755622864
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0100.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.1%
# START EPOCH 0101 (lr=1e-02)
# END EPOCH 0101 time spent: 251.3747639656067
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0101.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 64.1%
# START EPOCH 0102 (lr=1e-02)
# END EPOCH 0102 time spent: 250.94605135917664
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0102.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.9%
# START EPOCH 0103 (lr=1e-02)
# END EPOCH 0103 time spent: 250.17028880119324
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0103.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.7%
# START EPOCH 0104 (lr=1e-02)
# END EPOCH 0104 time spent: 250.95155501365662
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0104.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.8%
# START EPOCH 0105 (lr=1e-02)
# END EPOCH 0105 time spent: 250.254634141922
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0105.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 67.9%
# START EPOCH 0106 (lr=1e-02)
# END EPOCH 0106 time spent: 250.78335309028625
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0106.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 67.2%
# START EPOCH 0107 (lr=1e-02)
# END EPOCH 0107 time spent: 249.3574869632721
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0107.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.1%
# START EPOCH 0108 (lr=1e-02)
# END EPOCH 0108 time spent: 250.9567985534668
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0108.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.5%
# START EPOCH 0109 (lr=1e-02)
# END EPOCH 0109 time spent: 250.3723165988922
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0109.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.4%
# START EPOCH 0110 (lr=1e-02)
# END EPOCH 0110 time spent: 250.35155820846558
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0110.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 69.8%
# START EPOCH 0111 (lr=1e-02)
# END EPOCH 0111 time spent: 249.23071932792664
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0111.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 62.3%
# START EPOCH 0112 (lr=1e-02)
# END EPOCH 0112 time spent: 251.64187121391296
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0112.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.5%
# START EPOCH 0113 (lr=1e-02)
# END EPOCH 0113 time spent: 249.33369755744934
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0113.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.1%
# START EPOCH 0114 (lr=1e-02)
# END EPOCH 0114 time spent: 251.07506155967712
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0114.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 69.5%
# START EPOCH 0115 (lr=1e-02)
# END EPOCH 0115 time spent: 250.26697325706482
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0115.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.3%
# START EPOCH 0116 (lr=1e-02)
# END EPOCH 0116 time spent: 250.86256289482117
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0116.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.7%
# START EPOCH 0117 (lr=1e-02)
# END EPOCH 0117 time spent: 250.20769619941711
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0117.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 68.8%
# START EPOCH 0118 (lr=1e-02)
# END EPOCH 0118 time spent: 248.53576970100403
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0118.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.8%
# START EPOCH 0119 (lr=1e-02)
# END EPOCH 0119 time spent: 252.9446108341217
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 64.9%
# ATTACK LinfAttack	accuracy: 27.7%
# ATTACK L2Attack	accuracy: 30.2%
# ATTACK JPEGLinfAttack	accuracy: 12.4%
# ATTACK FogAttack	accuracy: 7.9%
# ATTACK StAdvAttack	accuracy: 51.0%
# ATTACK ReColorAdvAttack	accuracy: 62.0%
# ATTACK LagrangePerceptualAttack	accuracy: 30.4%
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0119.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.5%
# START EPOCH 0120 (lr=1e-02)
# END EPOCH 0120 time spent: 251.36491870880127
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0120.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.0%
# START EPOCH 0121 (lr=1e-02)
# END EPOCH 0121 time spent: 249.7124514579773
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0121.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.6%
# START EPOCH 0122 (lr=1e-02)
# END EPOCH 0122 time spent: 250.15720796585083
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0122.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.8%
# START EPOCH 0123 (lr=1e-02)
# END EPOCH 0123 time spent: 249.4310393333435
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0123.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 66.2%
# START EPOCH 0124 (lr=1e-02)
# END EPOCH 0124 time spent: 250.19713735580444
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0124.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 63.0%
# START EPOCH 0125 (lr=1e-02)
# END EPOCH 0125 time spent: 249.96234464645386
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0125.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.8%
# START EPOCH 0126 (lr=1e-02)
# END EPOCH 0126 time spent: 250.73955941200256
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0126.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 65.2%
# START EPOCH 0127 (lr=1e-02)
# END EPOCH 0127 time spent: 250.41885662078857
# BEGIN VALIDATION
# CHECKPOINT data/logs/cifar/trades-wrn/FastLagrangePerceptualAttack(model, bound=0.5, num_iterations=10)-only_attack_correct/0127.ckpt.pth
# BEGIN VALIDATION
# ATTACK NoAttack	accuracy: 61.9%
# START EPOCH 0128 (lr=1e-02)
